# %%
import json
import csv
import os
from datetime import datetime
from confluent_kafka import Consumer, KafkaError, TopicPartition

# %%
# kafka configuration
consumer_config = {
    'bootstrap.servers': 'kafka2:9093,kafka1:9092',  # Endereço do(s) broker(s) Kafka
    'group.id': 'consumo-impacta',        # Identificador do grupo de consumidores
    'auto.offset.reset': 'earliest',         # Lê todas as mensagens disponíveis no tópico
    'client.id': 'consumidor_do_kafka'            # nome do client conectado
}
consumer = Consumer(consumer_config)
topic = f'impacta'  # Substitua pelo nome do seu tópico Kafka
partition = 0
offset = 0  # colocando 0, vmaos consumir sempre desde o inicio

# Atribua a partição e o offset ao consumidor
consumer.assign([TopicPartition(topic, partition, offset)])
# consumer.subscribe([topic])

# %%
# Função para salvar mensagens em CSV
def save_to_csv(messages, filename):
    messages = [json.loads(message.decode('utf-8')) for message in messages]
    keys = messages[0].keys()
    with open(filename, 'w', newline='') as output_file:
        dict_writer = csv.DictWriter(output_file, fieldnames=keys)
        dict_writer.writeheader()
        dict_writer.writerows(messages)

# %%
# Consumir mensagens e salvar em CSV a cada minuto
messages = []
start_time = datetime.now()

# %%
contador = 0
while (contador <= 10):
    print(contador)
    msg = consumer.poll(1)
    if msg is None:
        contador = contador + 1
        continue
    if msg.error():
        if msg.error().code() == KafkaError._PARTITION_EOF:
            print('Fim da Partição')
        else:
            print('Erro no Consumidor: {}'.format(msg.error()))
    else:
        print('Recebido: {}'.format(msg.value()))
        # Pega o valor da mensagem
        data = msg.value()

        messages.append(data)
        current_time = datetime.now()
        if (current_time - start_time).seconds >= 60:
            filename = f"messages_{start_time.strftime('%Y%m%d_%H%M')}.csv"
            save_to_csv(messages, filename)
            print(f"Saved {len(messages)} messages to {filename}")
            messages = []
            start_time = current_time
        contador = 0
consumer.close()
# Out:
# 0
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a like by user2", "timestamp": "2025-11-19T14:53:53.845075"}'
# 0
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:53:54.855437"}'
# 0
# Recebido: b'{"user": "user1", "action": "comment", "message": "This is a like by user3", "timestamp": "2025-11-19T14:53:55.858570"}'
# 0
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a like by user3", "timestamp": "2025-11-19T14:53:56.859358"}'
# 0
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a post by user3", "timestamp": "2025-11-19T14:53:57.860140"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "comment", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:53:58.868459"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a post by user1", "timestamp": "2025-11-19T14:53:59.872517"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:00.880564"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a post by user2", "timestamp": "2025-11-19T14:54:01.887243"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:02.893131"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:03.907107"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a post by user1", "timestamp": "2025-11-19T14:54:04.907713"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "like", "message": "This is a comment by user2", "timestamp": "2025-11-19T14:54:05.911860"}'
# 0
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a like by user1", "timestamp": "2025-11-19T14:54:06.912849"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "comment", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:07.913742"}'
# 0
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:08.914200"}'
# 0
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a post by user2", "timestamp": "2025-11-19T14:54:07.607949"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:08.610170"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:09.613078"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "post", "message": "This is a comment by user2", "timestamp": "2025-11-19T14:54:10.615762"}'
# 0
# Recebido: b'{"user": "user2", "action": "like", "message": "This is a like by user1", "timestamp": "2025-11-19T14:54:11.616513"}'
# 0
# Recebido: b'{"user": "user1", "action": "post", "message": "This is a post by user1", "timestamp": "2025-11-19T14:54:12.617707"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a comment by user3", "timestamp": "2025-11-19T14:54:13.619891"}'
# 0
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:14.624870"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "like", "message": "This is a comment by user3", "timestamp": "2025-11-19T14:54:15.626083"}'
# 0
# Recebido: b'{"user": "user1", "action": "like", "message": "This is a post by user1", "timestamp": "2025-11-19T14:54:16.626663"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "comment", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:17.631768"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a comment by user2", "timestamp": "2025-11-19T14:54:18.632603"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:19.633540"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a like by user3", "timestamp": "2025-11-19T14:54:20.635980"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a post by user2", "timestamp": "2025-11-19T14:54:21.638142"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:22.640082"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "like", "message": "This is a like by user1", "timestamp": "2025-11-19T14:54:23.642698"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:24.645341"}'
# 0
# Recebido: b'{"user": "user1", "action": "post", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:25.646319"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:26.646669"}'
# 0
# 1
# Recebido: b'{"user": "user1", "action": "post", "message": "This is a like by user1", "timestamp": "2025-11-19T14:54:27.649661"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "like", "message": "This is a like by user3", "timestamp": "2025-11-19T14:54:28.650364"}'
# 0
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:29.650872"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:30.651512"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:31.652697"}'
# 0
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a post by user1", "timestamp": "2025-11-19T14:54:32.653705"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:33.657201"}'
# 0
# Recebido: b'{"user": "user1", "action": "comment", "message": "This is a post by user2", "timestamp": "2025-11-19T14:54:34.657679"}'
# 0
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a like by user3", "timestamp": "2025-11-19T14:54:35.659410"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "comment", "message": "This is a comment by user1", "timestamp": "2025-11-19T14:54:36.663133"}'
# 0
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:35.356765"}'
# 0
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a comment by user2", "timestamp": "2025-11-19T14:54:36.357389"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a post by user2", "timestamp": "2025-11-19T14:54:37.359173"}'
# 0
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a comment by user2", "timestamp": "2025-11-19T14:54:38.359701"}'
# 0
# Recebido: b'{"user": "user3", "action": "post", "message": "This is a like by user2", "timestamp": "2025-11-19T14:54:39.360191"}'
# 0
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a like by user1", "timestamp": "2025-11-19T14:54:40.363625"}'
# 0
# 1
# Recebido: b'{"user": "user2", "action": "post", "message": "This is a post by user3", "timestamp": "2025-11-19T14:54:41.370960"}'
# 0
# 1
# Recebido: b'{"user": "user3", "action": "comment", "message": "This is a comment by user3", "timestamp": "2025-11-19T14:54:42.374034"}'
# 0
