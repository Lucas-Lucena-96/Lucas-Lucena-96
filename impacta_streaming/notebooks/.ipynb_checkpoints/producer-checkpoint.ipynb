# %%
import time
import json
from confluent_kafka import Producer
from confluent_kafka.admin import AdminClient
import random
from datetime import datetime

# %%
#função de callback do producer. para ver se teve erro ou sucesso.

def delivery_report(err, msg):
    if err is not None:
        print('Falha : {}'.format(err))
    else:
        print('Sucesso {} [{}]'.format(msg.topic(), msg.partition()))

# %%
# kafka configuration
conf = {
    'bootstrap.servers': 'kafka1:9092,kafka2:9093'
}

# %%
#Remove o tópico antes de iniciar o envio
admin_client = AdminClient(conf)
admin_client.delete_topics(topics=[f"impacta"])
# Out:
# {'impacta': <Future at 0x7f2262057890 state=running>}

# %%
# kafka producer init
producer = Producer(conf)

# %%
#producer.produce(f"f1-{ano}", key=None, value=line.encode('utf-8'), callback=delivery_report)

# %%
# Conectar ao Kafka
#producer = KafkaProducer(bootstrap_servers='kafka1:9092',
#                         value_serializer=lambda v: json.dumps(v).encode('utf-8'))

# Função para gerar mensagens simuladas
def generate_message():
    users = ["user1", "user2", "user3"]
    actions = ["post", "like", "comment"]
    return {
        "user": random.choice(users),
        "action": random.choice(actions),
        "message": f"This is a {random.choice(actions)} by {random.choice(users)}",
        "timestamp": datetime.now().isoformat()  # Adicionar timestamp
    }

# Enviar mensagens continuamente
while True:
    message = generate_message()
    producer.produce(f"impacta", key=None, value=json.dumps(message), callback=delivery_report)
    print(f"Sent: {message}")
    time.sleep(1)  # Esperar 1 segundo entre mensagens
# Out:
# Sent: {'user': 'user2', 'action': 'comment', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:53:53.845075'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:53:54.855437'}
# Sent: {'user': 'user1', 'action': 'comment', 'message': 'This is a like by user3', 'timestamp': '2025-11-19T14:53:55.858570'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a like by user3', 'timestamp': '2025-11-19T14:53:56.859358'}
# Sent: {'user': 'user2', 'action': 'comment', 'message': 'This is a post by user3', 'timestamp': '2025-11-19T14:53:57.860140'}
# Sent: {'user': 'user1', 'action': 'comment', 'message': 'This is a comment by user1', 'timestamp': '2025-11-19T14:53:58.868459'}
# Sent: {'user': 'user2', 'action': 'post', 'message': 'This is a post by user1', 'timestamp': '2025-11-19T14:53:59.872517'}
# Sent: {'user': 'user3', 'action': 'post', 'message': 'This is a comment by user1', 'timestamp': '2025-11-19T14:54:00.880564'}
# Sent: {'user': 'user3', 'action': 'post', 'message': 'This is a post by user2', 'timestamp': '2025-11-19T14:54:01.887243'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:02.893131'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:03.907107'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a post by user1', 'timestamp': '2025-11-19T14:54:04.907713'}
# Sent: {'user': 'user2', 'action': 'like', 'message': 'This is a comment by user2', 'timestamp': '2025-11-19T14:54:05.911860'}
# Sent: {'user': 'user2', 'action': 'comment', 'message': 'This is a like by user1', 'timestamp': '2025-11-19T14:54:06.912849'}
# Sent: {'user': 'user1', 'action': 'comment', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:07.913742'}
# Sent: {'user': 'user2', 'action': 'comment', 'message': 'This is a post by user3', 'timestamp': '2025-11-19T14:54:08.914200'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a post by user2', 'timestamp': '2025-11-19T14:54:07.607949'}
# Sent: {'user': 'user2', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:08.610170'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:09.613078'}
# Sent: {'user': 'user1', 'action': 'post', 'message': 'This is a comment by user2', 'timestamp': '2025-11-19T14:54:10.615762'}
# Sent: {'user': 'user2', 'action': 'like', 'message': 'This is a like by user1', 'timestamp': '2025-11-19T14:54:11.616513'}
# Sent: {'user': 'user1', 'action': 'post', 'message': 'This is a post by user1', 'timestamp': '2025-11-19T14:54:12.617707'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a comment by user3', 'timestamp': '2025-11-19T14:54:13.619891'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:14.624870'}
# Sent: {'user': 'user2', 'action': 'like', 'message': 'This is a comment by user3', 'timestamp': '2025-11-19T14:54:15.626083'}
# Sent: {'user': 'user1', 'action': 'like', 'message': 'This is a post by user1', 'timestamp': '2025-11-19T14:54:16.626663'}
# Sent: {'user': 'user1', 'action': 'comment', 'message': 'This is a post by user3', 'timestamp': '2025-11-19T14:54:17.631768'}
# Sent: {'user': 'user3', 'action': 'comment', 'message': 'This is a comment by user2', 'timestamp': '2025-11-19T14:54:18.632603'}
# Sent: {'user': 'user3', 'action': 'comment', 'message': 'This is a comment by user1', 'timestamp': '2025-11-19T14:54:19.633540'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a like by user3', 'timestamp': '2025-11-19T14:54:20.635980'}
# Sent: {'user': 'user2', 'action': 'post', 'message': 'This is a post by user2', 'timestamp': '2025-11-19T14:54:21.638142'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a comment by user1', 'timestamp': '2025-11-19T14:54:22.640082'}
# Sent: {'user': 'user3', 'action': 'like', 'message': 'This is a like by user1', 'timestamp': '2025-11-19T14:54:23.642698'}
# Sent: {'user': 'user3', 'action': 'comment', 'message': 'This is a like by user2', 'timestamp': '2025-11-19T14:54:24.645341'}
# Sent: {'user': 'user1', 'action': 'post', 'message': 'This is a comment by user1', 'timestamp': '2025-11-19T14:54:25.646319'}
# Sent: {'user': 'user3', 'action': 'comment', 'message': 'This is a post by user3', 'timestamp': '2025-11-19T14:54:26.646669'}
